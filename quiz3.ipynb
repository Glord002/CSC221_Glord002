# %% [markdown]
# <a href="https://colab.research.google.com/github/Glord002/CSC221_Glord002/blob/main/quiz3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1) abs() Returns the absolute value of a number here is example
num1 = -10

abs_num1 = abs(num1)

print("Absolute value of", num1, "is", abs_num1)

#2) zip() Returns an iterator, from two or more iterators here is example
list1 = [1, 2, 3]
list2 = ['a', 'b', 'c']
list3 = [True, False, True]

zipped = zip(list1, list2, list3)

result = list(zipped)

print(result)


x = zip(a, b)
#3 sum() Sums the items of an iterator
a = (1, 2, 3, 4, 5)
x = sum(a)
#4 next() Returns the next item in an iterable
my_iterator = iter([1, 2, 3, 4, 5])

next_item1 = next(my_iterator)
print("Next item:", next_item1)  # Output: Next item: 1

next_item2 = next(my_iterator)
print("Next item:", next_item2)  # Output: Next item: 2

#5 oct() Converts a number into an octal
num = 21

oct_representation = oct(num)

print("Octal representation of", num, "is:", oct_representation)

#6 pow()Returns the value of x to the power of y
base = 2
exponent = 3

result = pow(base, exponent)

print("Result:", result)
#7 dir() Returns a list of the specified object's properties and methods
print("Names in current local scope:")
print(dir())

import math
print("\nNames in 'math' module:")
print(dir(math))

my_list = [1, 2, 3]
print("\nNames in 'my_list' object:")
print(dir(my_list))

#8 len() Returns the length of an object
string_length = len("Hello, world!")
print("Length of the string:", string_length)

my_list = [1, 2, 3, 4, 5]
list_length = len(my_list)
print("Length of the list:", list_length)

my_dict = {"a": 1, "b": 2, "c": 3}
dict_length = len(my_dict)
print("Length of the dictionary:", dict_length)

#9 list() Returns a list
my_string = "Hello"
char_list = list(my_string)
print(char_list)

#10 all() Returns True if all items in an iterable object are true
my_list1 = [True, True, True, True]
result1 = all(my_list1)
print("Result 1:", result1)  # Output: Result 1: True

#11 any() Returns True if any item in an iterable object is true
my_list2 = [False, False, False, False]
result2 = any(my_list2)
print("Result 2:", result2)  # Output: Result 2: False

#12 bin() Returns the binary version of a number
num1 = 10
binary1 = bin(num1)
print("Binary representation of", num1, "is:", binary1)

#13 bytes() Returns a bytes object
null_bytes = bytes(5)
print("Null bytes:", null_bytes)

#14 float() Returns a floating point number
integer_num = 42
float_num = float(integer_num)
print("Float representation of", integer_num, "is:", float_num)

#15 hex() Converts a number into a hexadecimal value
num1 = 16
hex1 = hex(num1)
print("Hexadecimal representation of", num1, "is:", hex1)

#16 max() Returns the largest item in an iterable
max_value = max(10, 20, 30, 40, 50)
print("Maximum value:", max_value)

#17 input() Allowing user input
name = input("Enter your name: ")

print("Hello, " + name + "! Nice to meet you.")

#18 int() Returns an integer number
string_num = "123"
integer_num = int(string_num)
print("Integer representation of", string_num, "is:", integer_num)

#19 range() Returns a sequence of numbers, starting from 0 and increments by 1 (by default)
sequence = range(5)
print("Sequence:", list(sequence))  # Output: Sequence: [0, 1, 2, 3, 4]

#20 complex() Returns a complex number
complex_num = complex(2, 3)
print("Complex number:", complex_num)
# Out:
# Absolute value of -10 is 10
# [(1, 'a', True), (2, 'b', False), (3, 'c', True)]
# Next item: 1
# Next item: 2
# Octal representation of 21 is: 0o25
# Result: 8
# Names in current local scope:
# ...
