# %% [markdown]
# <a href="https://colab.research.google.com/github/Glord002/CSC221_Glord002/blob/main/Assignment7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#6.1 TIY
person = {
    'first_name': 'George',
    'last_name': 'Lordkipanidze',
    'age': 20,
    'city': 'New York'
}

print("First Name:", person['first_name'])
print("Last Name:", person['last_name'])
print("Age:", person['age'])
print("City:", person['city'])
#6.2 TIY
favorite_numbers = {
    'George': 7,
    'Nick': 12,
    'David': 3,
    'Tamara': 21,
    'Liz': 8
}

for name, number in favorite_numbers.items():
    print(name + "'s favorite number is", number)
#6.3 TIY
glossary = {
    'variable': 'A name that is used to denote a value stored in memory.',
    'function': 'A named block of code that performs a specific task.',
    'loop': 'A control flow statement that allows code to be executed repeatedly.',
    'list': 'An ordered collection of items, which can be of different types.',
    'dictionary': 'A collection of key-value pairs, where each key is unique.'
}

for word, meaning in glossary.items():
    print(word + ":\n" + meaning + "\n")

#6.4 TIY
glossary = {
    'variable': 'A placeholder for storing data.',
    'list': 'A collection of items in a particular order.',
    'dictionary': 'A collection of key-value pairs.',
    'tuple': 'An immutable collection of items.',
    'function': 'A named block of code designed to perform a specific task.'
}

for term, meaning in glossary.items():
    print(f"{term.title()}: {meaning}")

glossary['loop'] = 'A programming construct that repeats a block of code.'
glossary['conditional statement'] = 'A statement that performs different actions depending on whether a condition is true or false.'
glossary['module'] = 'A file containing Python code that can be imported and used in another Python program.'
glossary['class'] = 'A blueprint for creating objects with specific properties and methods.'
glossary['method'] = 'A function that belongs to an object.'

print("\nAfter adding five more terms:")

for term, meaning in glossary.items():
    print(f"{term.title()}: {meaning}")



#6.11 TIY
cities = {
    "Berlin": {
        "country": "Gemany",
        "population": "approximately 3.6 Million",
        "fact": "Berlin Best place to go out at night because it has the best nightlife."
    },
    "New York": {
        "country": "United States",
        "population": "approximately 8.4 million",
        "fact": "New York City is often referred to as 'The Big Apple'."
    },
    "London": {
        "country": "United Kingdom",
        "population": "approximately 8.9 million",
        "fact": "London is home to the famous Tower Bridge."
    }
}

for city, info in cities.items():
    print(f"{city}:")
    print(f"  Country: {info['country']}")
    print(f"  Population: {info['population']}")
    print(f"  Fact: {info['fact']}")
    print()
#assigment
with open("grades.txt", "w") as file:
    file.write("Alice,85\n")
    file.write("Bob,75\n")
    file.write("Charlie,90\n")
    file.write("David,80\n")
    file.write("Eve,95\n")

def create_grade_dictionary(file_name):
    grade_dict = {}
    with open(file_name, 'r') as file:
        for line in file:
            name, grade = line.strip().split(',')
            grade_dict[name] = float(grade)
    return grade_dict

def print_sorted_by_names(grade_dict):
    sorted_names = sorted(grade_dict.keys())
    print("Sorted by names:")
    for name in sorted_names:
        print(f"{name}: {grade_dict[name]}")

def print_sorted_by_grades(grade_dict):
    sorted_grades = sorted(grade_dict.items(), key=lambda x: x[1], reverse=True)
    print("Sorted by grades (from highest to lowest):")
    for name, grade in sorted_grades:
        print(f"{name}: {grade}")


file_name = "grades.txt"
grade_dict = create_grade_dictionary(file_name)

print_sorted_by_names(grade_dict)
print()
print_sorted_by_grades(grade_dict)
# Out:
# First Name: George
# Last Name: Lordkipanidze
# Age: 20
# City: New York
# George's favorite number is 7
# Nick's favorite number is 12
# David's favorite number is 3
# Tamara's favorite number is 21
# Liz's favorite number is 8
# variable:
# A name that is used to denote a value stored in memory.
#
# function:
# A named block of code that performs a specific task.
#
# loop:
# A control flow statement that allows code to be executed repeatedly.
#
# list:
# An ordered collection of items, which can be of different types.
#
# dictionary:
# A collection of key-value pairs, where each key is unique.
#
# Variable: A placeholder for storing data.
# List: A collection of items in a particular order.
# Dictionary: A collection of key-value pairs.
# Tuple: An immutable collection of items.
# Function: A named block of code designed to perform a specific task.
#
# After adding five more terms:
# Variable: A placeholder for storing data.
# List: A collection of items in a particular order.
# ...
