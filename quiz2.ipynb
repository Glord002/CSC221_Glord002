# %% [markdown]
# <a href="https://colab.research.google.com/github/Glord002/CSC221_Glord002/blob/main/quiz2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1none)keyword none is used to define a null value or no value at all and here is the example
x = None

if x:
  print("Do you think None is True?")
elif x is False:
  print ("Do you think None is False?")
else:
  print("None is not True, or False, None is just None...")

#2false) The keyword false is used to a Boolean value, and the result of a comparison operation. The False keyword is the same as 0 ( True is the same as 1).
#here is the example

x = 5
y = 10

result = x > y

print(result)  # This will print False because 5 is not greater than 10

#3and)The keyword and Returns True if both statements are true
#4 or) The key word or Returns True if one of the statements is true
#5 not) The keyword not Reverse the result, returns False if the result is true
# here is the example for all three

# Example using 'and'
x = 5
y = 10

if x > 0 and y > 0:
    print("Both x and y are positive.")

# Example using 'or'
name = "Alice"

if name == "Alice" or name == "Bob":
    print("The name is either Alice or Bob.")

# Example using 'not'
flag = False

if not flag:
    print("The flag is False.")
#6 true) the keyword true means The True keyword is a Boolean value and the result of a comparison operation
#The True keyword is the same as 1 ( False is the same as 0) here is the example

email_verified = True

if email_verified:
    print("Email address has been verified.")
else:
    print("Please verify your email address.")
#7 as) the keyword "as" means to create an alias and here is an example
import math as m

result = m.sqrt(25)

print("Square root of 25:", result)

#8 async) keyword async means to declare the function as a couroutine and here is an example.
import asyncio

async def main():
    print('hello')
    await asyncio.sleep(1)
    print('world')

#9 assert) the keyword assert mean used when debugging code.
#The assert keyword lets you test if a condition in your code returns True here is an example
def calculate_area(length, width):
    assert length > 0 and width > 0, "Length and width must be positive numbers"
    return length * width

area = calculate_area(5, 4)
print("Area of the rectangle:", area)


#10 break) the keyword break means In Python break allows you to exit a loop when an external condition is met and here is an example
# Example of using the 'break' keyword to exit a loop
# List of numbers
numbers = [1, 2, 3, 4, 5,]

# Iterate over the list
for number in numbers:
    print(number)
    if number == 3:
        break  # Exit the loop when the number reaches 3

print("Loop ended.")

#11 await) keyword await is used to signify that the coroutine should pause execution until the awaited task completes here is an example.
import asyncio

async def fetch_data():
    print("Fetching data...")
    await asyncio.sleep(2)
    return "Data fetched successfully"

async def process_data():
    print("Processing data...")
    await asyncio.sleep(1)
    print("Data processed successfully")

#12 continiue) the keyword continiue is use in Python is used to skip the remaining code inside a loop for the current iteration only and here is the example
for i in range(10):
    if i % 2 != 0:
        continue
    print(i)
#13 class) the keyword class is allows you to exit a loop when an external condition is met and here is the example
for num in range(0,10):
    if num == 5:
        break
    print(f'Iteration: {num}')

#14 def) the keyword def is short for “define”. It's a keyword that you need to define a function (aka method) and here is the example
def add_numbers(a, b):
    """
    Adds two numbers together and returns the result.

    Parameters:
    a (int or float): The first number.
    b (int or float): The second number.

    Returns:
    int or float: The sum of the two numbers.
    """
    return a + b

result = add_numbers(3, 5)
print("The sum of 3 and 5 is:", result)
#15 elif)The “elif” keyword in Python, stands for “else if”. It can be used in conditional statements to check for multiple conditions.
#For example, if the first condition is false, it moves on to the next “elif” statement to check if that condition is true.
score = 85

if score >= 90:
    grade = 'A'
elif score >= 80:
    grade = 'B'
elif score >= 70:
    grade = 'C'
elif score >= 60:
    grade = 'D'
else:
    grade = 'F'

print("Your grade is:", grade)

#16 del) the keyword del The del keyword is used to delete objects.
#In Python,In Python everything is an object, so the del keyword can also be used to delete variables, lists, or parts of a list etc here is an example
x = ["apple", "banana", "cherry"]

del x[0]

print(x)

#17 except) the keyword except used in try... except blocks. It defines a block of code to run if the try block raises an error. here is an example
x = "hello"

try:
  x > 3
except NameError:
  print("You have a variable that is not defined.")
except TypeError:
  print("You are comparing values of different type")

#18 else) The else keyword is used in conditional statements (if statements), and decides what to do if the condition is False here is the example
x = 5

try:
  x > 10
except:
  print("Something went wrong")
else:
  print("The 'Try' code was executed without raising any errors!")

#19 for) the word for is used to create a for loop here is an example
fruits = ["apple", "banana", "cherry"]

for x in fruits:
  print(x)

#20 finally) the keyword finally It defines a block of code to run when the try except else block is final.
#The finally block will be executed no matter if the try block raises an error or not here is an example
try:
  x > 3
except:
  print("Something went wrong")
else:
  print("Nothing went wrong")
finally:
  print("The try...except block is finished")
#21 from) The from keyword is used to import only a specified section from a module here is an example
from datetime import time

x = time(hour=15)

print(x)
#22 if) the keyword if The if keyword is used to create conditional statements here is an example
x = 5
if x > 6:
  print("YES")
else:
  print("NO")
#23 The global keyword is used to create global variables from a no-global scope, e.g. inside a function.
def myfunction():
  global x
  x = "hello"

myfunction()

print(x)

#24 in) The in keyword is used to check if a value is present in a sequence here is an example
fruits = ["apples", "oranges", "cherry"]

for x in fruits:
  print(x)
#25 import) the keyword import is to make code in one module available in another here is an example
import datetime

x = datetime.datetime.now()
print(x)
#26 lambda) keyword lambda in Python is for defining the anonymous function here is an example
x = lambda a : a + 10

print(x(5))

#27 is) a keyword is in Python used to test object identity here is an example
x = ["apple", "banana", "cherry"]

y = x

print(x is y)

#28 The nonlocal keyword is used to work with variables inside nested functions, where the variable should not belong to the inner function here is an example
def myfunc1():
  x = "John"
  def myfunc2():
    nonlocal x
    x = "hello"
  myfunc2()
  return x

print(myfunc1())

#29 raise) Python raise Keyword is used to raise exceptions or errors for example
x = "hello"

if not type(x) is int:
  raise TypeError("Only integers are allowed")

#30 pass) the keyword pass is used as a placeholder for future code
a = 33
b = 200

if b > a:
  pass
#31 try) the word try is used in try except blocks. It defines a block of code test if it contains any errors here is an example
try:
  x > 3
except:
  Exception("Something went wrong")
#32 return) keyword return is to exit a function and return a value for example
def myfunction():
  return 3+3
  print("Hello, World!")

print(myfunction())

#33 while) The while keyword is used to create a while loop. A while loop will continue until the statement is false for example
x = 0

while x < 9:
  print(x)
  x = x + 1

#34 with) In python the with keyword is used when working with unmanaged resources for example
with open('example.txt', 'r') as file:
    data = file.read()
    print(data)

#35 yield) the keyword is used to return a list of values from a function for example
def myFunc():
  yield "Hello"
  yield 51
  yield "Good Bye"

x = myFunc()

for z in x:
  print(z)
# Out:
# None is not True, or False, None is just None...
# False
# Both x and y are positive.
# The name is either Alice or Bob.
# The flag is False.
# Email address has been verified.
# Square root of 25: 5.0
# Area of the rectangle: 20
# 1
# 2
# 3
# Loop ended.
# 0
# 2
# 4
# 6
# 8
# Iteration: 0
# Iteration: 1
# Iteration: 2
# Iteration: 3
# Iteration: 4
# The sum of 3 and 5 is: 8
# Your grade is: B
# ['banana', 'cherry']
# You are comparing values of different type
# The 'Try' code was executed without raising any errors!
# apple
# banana
# cherry
# Something went wrong
# The try...except block is finished
# 15:00:00
# NO
# hello
# apples
# oranges
# cherry
# 2024-05-16 05:21:45.601656
# 15
# True
# hello
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-edd0452cfdb0> in <cell line: 249>()
#     248
#     249 if not type(x) is int:
# ...
