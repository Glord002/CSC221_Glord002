# %% [markdown]
# <a href="https://colab.research.google.com/github/Glord002/CSC221_Glord002/blob/main/Assignment6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
car = 'Lamborghini'
print("Is car == 'Lamborghini'? I predict True.")
print(car == 'subaru')

print("\nIs car == 'audi'? I predict False.")
print(car == 'audi')


name = 'George'
print("\nIs name == 'George'? I predict True.")
print(name == 'George')

print("\nIs name == 'George'? I predict False.")
print(name == 'George')


print("\nIs name.lower() == 'George'? I predict True.")
print(name.lower() == 'George')


num1 = 10
num2 = 5
print("\nIs num1 == num2 * 2? I predict True.")
print(num1 == num2 * 2)

print("\nIs num1 != num2? I predict True.")
print(num1 != num2)

print("\nIs num1 > num2? I predict True.")
print(num1 > num2)

print("\nIs num1 >= num2 + 5? I predict True.")
print(num1 >= num2 + 5)

print("\nIs num1 < num2? I predict False.")
print(num1 < num2)

print("\nIs num1 <= num2? I predict False.")
print(num1 <= num2)


age = 25
print("\nIs age > 18 and age < 30? I predict True.")
print(age > 18 and age < 30)

print("\nIs age < 18 or age > 30? I predict False.")
print(age < 18 or age > 30)


alien_color = 'green'


if alien_color == 'green':
    print("The player just earned 5 points.")


if alien_color != 'green':
    pass

alien_color = 'yellow'


if alien_color == 'green':
    print("The player just earned 5 points for shooting the alien.")
else:
    print("The player just earned 10 points.")


if alien_color == 'red':
    print("The player just earned 5 points for shooting the alien.")
else:
    print("The player just earned 10 points.")


alien_color = 'yellow'

if alien_color == 'green':
    print("The player earned 5 points.")
elif alien_color == 'yellow':
    print("The player earned 10 points.")
else:
    print("The player earned 15 points.")
alien_color = 'red'

if alien_color == 'green':
    print("The player earned 5 points.")
elif alien_color == 'yellow':
    print("The player earned 10 points.")
else:
    print("The player earned 15 points.")
alien_color = 'green'

if alien_color == 'green':
    print("The player earned 5 points.")
elif alien_color == 'yellow':
    print("The player earned 10 points.")
else:
    print("The player earned 15 points.")

age = 25

if age < 2:
    print("The person is a baby.")
elif age < 4:
    print("The person is a toddler.")
elif age < 13:
    print("The person is a kid.")
elif age < 20:
    print("The person is a teenager.")
elif age < 65:
    print("The person is an adult.")
else:
    print("The person is an elder.")

favorite_fruits = ['apple', 'banana', 'orange']

if 'apple' in favorite_fruits:
    print("You really like apples.")
if 'banana' in favorite_fruits:
    print("You really like bananas.")
if 'grape' in favorite_fruits:
    print("You really like grapes.")
if 'orange' in favorite_fruits:
    print("You really like oranges.")
if 'kiwi' in favorite_fruits:
    print("You really like kiwis.")

usernames = ['admin', 'George', 'Nick', 'David', 'Tamara']

for username in usernames:
    if username == 'admin':
        print("Hello admin, would you like to see a status report?")
    else:
        print(f"Hello {username.title()}, thank you for logging in again.")
usernames = []

if usernames:
    for username in usernames:
        if username == 'admin':
            print("Hello admin, would you like to see a status report?")
        else:
            print(f"Hello {username.title()}, thank you for logging in again.")
else:
    print("We need to find some users!")

current_users = ['admin', 'George', 'Nick', 'David', 'Tamara']
new_users = ['jane', 'George', 'NICK', 'David', 'Tamara']

current_users_lower = [user.lower() for user in current_users]

for new_user in new_users:
    if new_user.lower() in current_users_lower:
        print(f"Sorry, the username '{new_user}' is already taken. Please enter a new username.")
    else:
        print(f"The username '{new_user}' is available.")

numbers = list(range(1, 10))

for number in numbers:
    if number == 1:
        print(f"{number}st")
    elif number == 2:
        print(f"{number}nd")
    elif number == 3:
        print(f"{number}rd")
    else:
        print(f"{number}th")

#For 5-13 me my I wanted to write Datasets and probably game developer but I will stick with Dataset creating my own one I would explore data sets and here it goes.
dataset = [
    {"ID": 1, "Name": "George", "Age": 21, "Gender": "Male", "Occupation": "Musician", "Salary": 85000},
    {"ID": 2, "Name": "Nick", "Age": 45, "Gender": "Female", "Occupation": "Teacher", "Salary": 120000},
    {"ID": 3, "Name": "David", "Age": 34, "Gender": "Male", "Occupation": "Bar Owner", "Salary": 110000},
    {"ID": 4, "Name": "Tamara", "Age": 30, "Gender": "Female", "Occupation": "Plumber", "Salary": 55000},
    {"ID": 5, "Name": "Mariam", "Age": 50, "Gender": "Male", "Occupation": "Accountant", "Salary": 95000},
    {"ID": 6, "Name": "Shaun", "Age": 22, "Gender": "Female", "Occupation": "Game Developer", "Salary": 100000}
]

for person in dataset:
    print(f"Name: {person['Name']}, Age: {person['Age']}, Gender: {person['Gender']}, Occupation: {person['Occupation']}, Salary: {person['Salary']}")
# Out:
# Is car == 'Lamborghini'? I predict True.
# False
#
# Is car == 'audi'? I predict False.
# False
#
# Is name == 'George'? I predict True.
# True
#
# Is name == 'George'? I predict False.
# True
#
# Is name.lower() == 'George'? I predict True.
# False
#
# Is num1 == num2 * 2? I predict True.
# True
#
# Is num1 != num2? I predict True.
# True
#
# Is num1 > num2? I predict True.
# True
#
# Is num1 >= num2 + 5? I predict True.
# True
#
# Is num1 < num2? I predict False.
# False
#
# Is num1 <= num2? I predict False.
# False
#
# Is age > 18 and age < 30? I predict True.
# True
#
# Is age < 18 or age > 30? I predict False.
# False
# The player just earned 5 points.
# The player just earned 10 points.
# The player just earned 10 points.
# The player earned 10 points.
# The player earned 15 points.
# The player earned 5 points.
# The person is an adult.
# You really like apples.
# You really like bananas.
# You really like oranges.
# Hello admin, would you like to see a status report?
# ...
